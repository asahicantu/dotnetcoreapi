# %% [markdown]
# # This is my first test of jupyter notebooks
#
#
# **This is bold**
# *this is italic*

# %%
print('Hello World')
# Out:
# Hello World

# %%
int_type = 42
float_type = 3.14159
bool = True
hex_type = 0xff
oct_type = 0o23

from datetime import datetime 
today = datetime.now
str_type = "fd"

# %%
from IPython.display import Image
Image("https://i.imgur.com/v8vAyBu.jpg")

# %% [markdown]
# # Structured data
# *SQL

# %% [markdown]
# # Unstructured data
# *HTML

# %% [markdown]
# # Non structured data
# * docuents
# * PDF
